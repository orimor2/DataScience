# 41465 1000     297.8    303.6
# 41466  995     296.0    303.2
# 41467  990     294.6    301.9
# 41468  985     294.1    302.3
# 41469  960     295.0    303.6
# 41470  995     297.8    304.5
# 41471  995     299.6    304.9
# 41472  970     299.6    304.0

# %%
summary(nasa)
# Out:
#       lat              long            month            year
#  Min.   :-21.20   Min.   :-113.8   Min.   : 1.00   Min.   :1995
#  1st Qu.: -6.85   1st Qu.: -99.4   1st Qu.: 3.75   1st Qu.:1996
#  Median :  7.50   Median : -85.0   Median : 6.50   Median :1998
#  Mean   :  7.50   Mean   : -85.0   Mean   : 6.50   Mean   :1998
#  3rd Qu.: 21.85   3rd Qu.: -70.6   3rd Qu.: 9.25   3rd Qu.:1999
#  Max.   : 36.20   Max.   : -56.2   Max.   :12.00   Max.   :2000
#
#    cloudhigh       cloudlow        cloudmid         ozone
#  Min.   : 0.0   Min.   : 0.50   Min.   : 0.00   Min.   :232.0
#  1st Qu.: 1.5   1st Qu.:15.00   1st Qu.: 7.50   1st Qu.:254.0
#  Median : 8.5   Median :23.50   Median :14.00   Median :264.0
#  Mean   :12.0   Mean   :26.24   Mean   :15.27   Mean   :267.2
#  3rd Qu.:18.5   3rd Qu.:34.50   3rd Qu.:22.00   3rd Qu.:276.0
#  Max.   :62.5   Max.   :84.50   Max.   :83.50   Max.   :390.0
#                 NA's   :110
#     pressure         surftemp      temperature
#  Min.   : 615.0   Min.   :266.0   Min.   :269.1
#  1st Qu.: 995.0   1st Qu.:294.1   1st Qu.:295.5
#  Median :1000.0   Median :296.9   Median :299.2
#  Mean   : 985.4   Mean   :296.2   Mean   :297.9
#  3rd Qu.:1000.0   3rd Qu.:299.2   3rd Qu.:301.4
#  Max.   :1000.0   Max.   :314.9   Max.   :310.0

# %%
library(readr)
library(dplyr)
library(ggplot2)
library(mechkar)

# %%
rmse <- function(y,y_hat) {
    err <- sqrt(sum((y_hat-y)^2,na.rm=T)/length(y))
    return(err)
}

rmsle <- function(y,y_hat) {
    err <- sqrt(sum((log(y_hat+1)-log(y+1))^2,na.rm=T)/length(y))
    return(err)
}

# %%
err_res <- NULL

# %%
mod1 <- lm(temperature ~., data=train)
summary(mod1)
# Out:
# Error in is.data.frame(data): object 'train' not found
# Traceback:
#
# 1. lm(temperature ~ ., data = train)
# 2. eval(mf, parent.frame())
# 3. eval(mf, parent.frame())
# 4. stats::model.frame(formula = temperature ~ ., data = train, drop.unused.levels = TRUE)
# 5. model.frame.default(formula = temperature ~ ., data = train,
#  .     drop.unused.levels = TRUE)
# 6. is.data.frame(data)

# %%
pred1 <- predict(mod1,newdata=test)
rmse(test$temperature_volume,pred1)
rmsle(test$temperature_volume,pred1)
err_res <- rbind(err_res, data.frame(Name="Base Linear regression", Model="mod1", 
                                     RMSE=rmse(test$temperature_volume,pred1), 
                                     RMSLE=rmsle(test$temperature_volume,pred1)))
# Out:
# Error in predict(mod1, newdata = test): object 'mod1' not found
# Traceback:
#
# 1. predict(mod1, newdata = test)
